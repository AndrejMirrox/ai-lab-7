# %% [markdown]
# # 1.8 Выделение и взятие в рамку определенного региона изображения, ROI изображения

# %% [markdown]
# ### На заданном изображении выделить его характерный участок.

# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('pic/Cat.jpg')

# %% [markdown]
# Рисуем прямоугольник:

# %%
image = cv2.rectangle(img, (660, 270), (1380, 780), (255, 0, 255), 10)

# %%
plt.imshow(image)
plt.axis("off");
